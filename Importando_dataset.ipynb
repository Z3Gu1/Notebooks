# %% [markdown]
# <a href="https://colab.research.google.com/github/Z3Gu1/Notebooks/blob/main/Importando_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# Importação de pacotes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm

# url a importar
url_dados = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

# labels dos atributos do dataset
labels_atributos = ['Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# carga do dataset através do csv
dataset = pd.read_csv(url_dados, names=labels_atributos)

# verifica o tipo de iris
print(type(iris))

# exibe as 5 primeiras linhas
dataset.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 1    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 1    13.16        2.36  2.67               18.6        101           2.80
# 1    14.37        1.95  2.50               16.8        113           3.85
# 1    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 1        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 1        3.24                  0.30             2.81             5.68  1.03
# 1        3.49                  0.24             2.18             7.80  0.86
# 1        2.69                  0.39             1.82             4.32  1.04
#
# ...

# %%
dataset.shape
# Out:
# (178, 13)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 1 to 3
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcohol                       178 non-null    float64
#  1   Malic acid                    178 non-null    float64
#  2   Ash                           178 non-null    float64
#  3   Alcalinity of ash             178 non-null    float64
#  4   Magnesium                     178 non-null    int64
#  5   Total phenols                 178 non-null    float64
#  6   Flavanoids                    178 non-null    float64
#  7   Nonflavanoid phenols          178 non-null    float64
#  8   Proanthocyanins               178 non-null    float64
#  9   Color intensity               178 non-null    float64
#  10  Hue                           178 non-null    float64
#  11  OD280/OD315 of diluted wines  178 non-null    float64
# ...

# %%
dataset.tail(10)
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 3    13.58        2.58  2.69               24.5        105           1.55
# 3    13.40        4.60  2.86               25.0        112           1.98
# 3    12.20        3.03  2.32               19.0         96           1.25
# 3    12.77        2.39  2.28               19.5         86           1.39
# 3    14.16        2.51  2.48               20.0         91           1.68
# 3    13.71        5.65  2.45               20.5         95           1.68
# 3    13.40        3.91  2.48               23.0        102           1.80
# 3    13.27        4.28  2.26               20.0        120           1.59
# 3    13.17        2.59  2.37               20.0        120           1.65
# 3    14.13        4.10  2.74               24.5         96           2.05
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 3        0.84                  0.39             1.54         8.660000  0.74
# ...

# %%
dataset.describe()
# Out:
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
dataset.groupby('Proline').size()
# Out:
# Proline
# 278     1
# 290     1
# 312     1
# 315     1
# 325     1
#        ..
# 1480    1
# 1510    1
# 1515    1
# 1547    1
# 1680    1
# Length: 121, dtype: int64

# %%
dataset.corr(method = 'pearson')
# Out:
#                                Alcohol  Malic acid       Ash  \
# Alcohol                       1.000000    0.094397  0.211545
# Malic acid                    0.094397    1.000000  0.164045
# Ash                           0.211545    0.164045  1.000000
# Alcalinity of ash            -0.310235    0.288500  0.443367
# Magnesium                     0.270798   -0.054575  0.286587
# Total phenols                 0.289101   -0.335167  0.128980
# Flavanoids                    0.236815   -0.411007  0.115077
# Nonflavanoid phenols         -0.155929    0.292977  0.186230
# Proanthocyanins               0.136698   -0.220746  0.009652
# Color intensity               0.546364    0.248985  0.258887
# Hue                          -0.071747   -0.561296 -0.074667
# OD280/OD315 of diluted wines  0.072343   -0.368710  0.003911
# Proline                       0.643720   -0.192011  0.223626
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# ...

# %%
dataset.hist(figsize = (15,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b8e03d602ea0> in <module>
#       1 dataset.hist(figsize = (15,10))
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined
